# %%
pip install opencv-python pillow
# Out:
# Requirement already satisfied: opencv-python in c:\users\futuremind\.conda\envs\thiyamy\lib\site-packages (4.9.0.80)
# Requirement already satisfied: pillow in c:\users\futuremind\.conda\envs\thiyamy\lib\site-packages (10.2.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\futuremind\.conda\envs\thiyamy\lib\site-packages (from opencv-python) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from PIL import Image

base_dir = r"D:\TEAM IDEATORS\1_objective\dataset_raw"
classes = ["elephant", "cow", "dog"]

for cls in classes:
    folder = os.path.join(base_dir, cls)
    images = os.listdir(folder)
    count = 1

    for img_name in images:
        img_path = os.path.join(folder, img_name)

        try:
            img = Image.open(img_path).convert("RGB")
            new_name = f"{cls}_{count:04d}.jpg"
            new_path = os.path.join(folder, new_name)

            img.save(new_path, "JPEG")

            # Remove original file if different name
            if img_name != new_name:
                os.remove(img_path)

            count += 1

        except Exception as e:
            print(f"Skipped {img_name}: {e}")
